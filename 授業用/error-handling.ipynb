# %%
x = 1
y = 0

# %%
x / y  # ZeroDivisionError: division by zero
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 x / y
#
# ZeroDivisionError: division by zero

# %%
try:
    result = x / y
except ZeroDivisionError as e:
    print("Error: Cannot divide by zero.", e)
    print("Please provide a non-zero denominator.")
    result = None

print("Result:", result)
# Out:
# Error: Cannot divide by zero. division by zero
# Please provide a non-zero denominator.
# Result: None

# %%
try:
    result = x / z
except ZeroDivisionError:
    result = None
    print("エラーが発生しました。", e)
    print("0以外の値を指定してください。")
except NameError:
    result = None
    print("エラーが発生しました", e)
    print("変数が定義されていません。")

print("Result:", result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 try:
# ----> 2     result = x / z
#       3 except ZeroDivisionError:
#
# NameError: name 'z' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       7 except NameError:
#       8     result = None
# ----> 9     print("エラーが発生しました", e)
#      10     print("変数が定義されていません。")
#      12 print("Result:", result)
#
# NameError: name 'e' is not defined

# %%
z = 3
try:
    result = x / z
except ZeroDivisionError:
    result = None
    print("エラーが発生しました。", e)
    print("0以外の値を指定してください。")
except NameError:
    result = None
    print("エラーが発生しました", e)
    print("変数が定義されていません。")
else:
    print("エラーは発生しませんでした。")
finally:
    print("処理が終了しました。")

print("Result:", result)
# Out:
# エラーは発生しませんでした。
# 処理が終了しました。
# Result: 0.3333333333333333

# %%
try:
    result = x / y
except Exception as e:
    result = None
    print("エラーが発生しました。", e)
    print("エラーオブジェクト:", type(e))
    print("エラーメッセージ:", e.args)
else:
    print("エラーは発生しませんでした。")
finally:
    print("処理が終了しました。")

print("Result:", result)
# Out:
# エラーが発生しました。 division by zero
# エラーオブジェクト: <class 'ZeroDivisionError'>
# エラーメッセージ: ('division by zero',)
# 処理が終了しました。
# Result: None

# %%
import requests

# %%
url = 'https://www.musashi.ac.jp/anvalid-page'
response = requests.get(url)
print("Status Code:", response.status_code)
response.raise_for_status()  # This will raise an HTTPError for bad responses
# Out:
# Status Code: 404
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       2 response = requests.get(url)
#       3 print("Status Code:", response.status_code)
# ----> 4 response.raise_for_status()  # This will raise an HTTPError for bad responses
#
# File ~/dsprog_2025_2/.venv/lib/python3.12/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://www.musashi.ac.jp/anvalid-page

# %%
url = 'https://www.musashi.ac.jp/anvalid-page'
response = requests.get(url)
print("Status Code:", response.status_code)
response.raise_for_status()  # This will raise an HTTPError for bad responses
# Out:
# Status Code: 404
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2 response = requests.get(url)
#       3 print("Status Code:", response.status_code)
# ----> 4 response.raise_for_status()  # This will raise an HTTPError for bad responses
#
# File ~/dsprog_2025_2/.venv/lib/python3.12/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://www.musashi.ac.jp/anvalid-page

# %%
url = 'https://www.musashi.ac.jp/anvalid-page'

try:
    response = requests.get(url)
    response.raise_for_status()
except requests.exceptions.HTTPError as e:
    print("HTTPエラーが発生しました。", e)
except requests.exceptions.RequestException as e:
    print("リクエストエラーが発生しました。", e)
else:
    print("webページに正常にアクセスできました。")
finally:
    print("webスクレイピング処理が終了しました。")
# Out:
# HTTPエラーが発生しました。 404 Client Error: Not Found for url: https://www.musashi.ac.jp/anvalid-page
# webスクレイピング処理が終了しました。
